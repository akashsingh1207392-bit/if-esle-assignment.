# %% [markdown]
# # 1string.capitalize()

# %% [markdown]
# Converts the first character to uppercase and the rest to lowercase.

# %%
my_string = "akash"
print(my_string.capitalize()) 

my_string = "aKASH SINGH"
print(my_string.capitalize()) 

my_string = "123 akash"
print(my_string.capitalize())
# Out:
# Akash
# Akash singh
# 123 akash

# %% [markdown]
# # 2. string.casefold

# %% [markdown]
# Converts the string to lowercase more strongly than lower(), useful for case-insensitive comparison.

# %%
my_string = "AKASH"
print(my_string.casefold()) 

my_string = "Akash singh"
print(my_string.casefold()) 

first = "AKASH"
second = "akash"
print(first.casefold() == second.casefold())
# Out:
# akash
# akash singh
# True

# %% [markdown]
# # 3. string.center(width[, fillchar])

# %% [markdown]
# Returns a centered string using spaces or the given fill character.

# %%
my_string = "Akash"
print(my_string.center(12)) 

my_string = "Akash"
print(my_string.center(12, "-")) 

my_string = "Hi"
print(my_string.center(10, "*"))
# Out:
#    Akash
# ---Akash----
# ****Hi****

# %% [markdown]
# # 4. string.count(substring[, start[, end]])

# %% [markdown]
# Counts how many times a substring appears in the string.

# %%
my_string = "banana"
print(my_string.count("a")) 

my_string = "banana"
print(my_string.count("a", 2)) 

my_string = "banana"
print(my_string.count("a", 2, 5)) 

my_string = "Python is easy and Python is powerful"
print(my_string.count("Python"))
# Out:
# 3
# 2
# 1
# 2

# %% [markdown]
# # 5. string.encode(encoding='utf-8', errors='strict')

# %% [markdown]
# Converts the string into bytes using the given encoding.

# %%
# my_string = "Python"
print(my_string.encode()) 

my_string = "Python"
print(my_string.encode("utf-8")) 

my_string = "Hello123"
print(my_string.encode("ascii")) 

my_string = "cafe" + chr(233)
print(my_string.encode("ascii", errors="ignore"))
# Out:
# b'Python is easy and Python is powerful'
# b'Python'
# b'Hello123'
# b'cafe'

# %% [markdown]
# # 6. string.endswith(suffix[, start[, end]])

# %%
my_string = "welcome.py"
print(my_string.endswith(".py")) 

my_string = "image.jpeg"
print(my_string.endswith((".jpg", ".jpeg", ".png"))) 

my_string = "Python Programming"
print(my_string.endswith("Programming", 7)) 

my_string = "Python Programming"
print(my_string.endswith("Program", 7, 14))
# Out:
# True
# True
# True
# True

# %% [markdown]
# # 7. string.expandtabs(tabsize=8)

# %%
my_string = "Name\tAge"
print(my_string.expandtabs()) 

my_string = "Name\tAge"
print(my_string.expandtabs(4)) 

my_string = "A\tB\tC"
print(my_string.expandtabs(2))
# Out:
# Name    Age
# Name    Age
# A B C

# %% [markdown]
# # 8. string.find(substring[, start[, end]])

# %%
my_string = "hello world"
print(my_string.find("world")) 

my_string = "banana"
print(my_string.find("a", 2)) 

my_string = "banana"
print(my_string.find("a", 2, 5)) 

my_string = "Python"
print(my_string.find("Java"))
# Out:
# 6
# 3
# 3
# -1

# %% [markdown]
# # 9. string.format(*args, **kwargs)

# %%
my_string = "My name is {}"
print(my_string.format("Sachin")) 

my_string = "{} is learning {}"
print(my_string.format("Sachin", "Python")) 

my_string = "{name} is learning {course}"
print(my_string.format(name="Riya", course="Python")) 

my_string = "Total marks: {:.2f}"
print(my_string.format(95.678))
# Out:
# My name is Sachin
# Sachin is learning Python
# Riya is learning Python
# Total marks: 95.68

# %% [markdown]
# # 10. string.format_map(mapping)

# %%
student = {"name": "Riya", "course": "Python"}
print("{name} is learning {course}".format_map(student))

marks = {"subject": "Math", "score": 92}
print("{subject}: {score}".format_map(marks))

employee = {"name": "Sachin", "city": "Pune"}
print("{name} lives in {city}".format_map(employee))
# Out:
# Riya is learning Python
# Math: 92
# Sachin lives in Pune

# %% [markdown]
# # 11. string.index(substring[, start[, end]])

# %%
my_string = "hello world"
print(my_string.index("world")) 

my_string = "banana"
print(my_string.index("a", 2)) 

my_string = "banana"
print(my_string.index("a", 2, 5)) 

my_string = "Python"
try:
    print(my_string.index("Java")) 
except ValueError:
    print("substring not found")
# Out:
# 6
# 3
# 3
# substring not found

# %% [markdown]
# # 12. string.isalnum()

# %%
my_string = "Python123"
print(my_string.isalnum())

my_string = "Python 123"
print(my_string.isalnum()) 

my_string = "Python_123"
print(my_string.isalnum()) 

my_string = "2026"
print(my_string.isalnum())
# Out:
# True
# False
# False
# True

# %% [markdown]
# # 13. string.isalpha()

# %%
my_string = "Python"
print(my_string.isalpha()) 

my_string = "Python123"
print(my_string.isalpha()) 

my_string = "Python Sachin"
print(my_string.isalpha()) 

my_string = "HelloWorld"
print(my_string.isalpha())
# Out:
# True
# False
# False
# True

# %% [markdown]
# # 14. string.isascii()

# %%
my_string = "Python123"
print(my_string.isascii()) 

my_string = "Hello!"
print(my_string.isascii()) 

my_string = "cafe" + chr(233)
print(my_string.isascii())
# Out:
# True
# True
# False

# %% [markdown]
# # 15. string.isdecimal()

# %%
my_string = "12345"
print(my_string.isdecimal()) 

my_string = "12.5"
print(my_string.isdecimal()) 

my_string = "123abc"
print(my_string.isdecimal()) 

my_string = "2026"
print(my_string.isdecimal())
# Out:
# True
# False
# False
# True

# %% [markdown]
# # 16. string.isdigit()

# %%
my_string = "2026"
print(my_string.isdigit())

my_string = "20a6"
print(my_string.isdigit()) 

my_string = "007"
print(my_string.isdigit())

my_string = "12.5"
print(my_string.isdigit())
# Out:
# True
# False
# True
# False

# %% [markdown]
# # 17. string.isidentifier()

# %%
my_string = "student_name"
print(my_string.isidentifier())

my_string = "2student"
print(my_string.isidentifier())

my_string = "student name"
print(my_string.isidentifier())

my_string = "student_name2"
print(my_string.isidentifier())
# Out:
# True
# False
# False
# True

# %% [markdown]
# # 18. string.islower()

# %%
my_string = "python"
print(my_string.islower()) # All letters are lowercase

my_string = "Python"
print(my_string.islower()) # P is uppercase

my_string = "python123"
print(my_string.islower()) # Numbers do not affect lowercase check

my_string = "python_sachin"
print(my_string.islower()) # Underscore does not affect lowercase check
# Out:
# True
# False
# True
# True

# %% [markdown]
# # 19. string.isnumeric()

# %%
my_string = "12345"
print(my_string.isnumeric()) # Numbers only

my_string = "123abc"
print(my_string.isnumeric()) # Letters make it False

my_string = "007"
print(my_string.isnumeric()) # Leading zeros are numeric

my_string = "12.5"
print(my_string.isnumeric()) # Dot makes it False
# Out:
# True
# False
# True
# False

# %% [markdown]
# # 20. string.isprintable()

# %%
my_string = "Hello Python"
print(my_string.isprintable()) # Normal text is printable

my_string = "Hello\nPython"
print(my_string.isprintable()) # Newline is not printable

my_string = "123 @ Python"
print(my_string.isprintable()) # Symbols and spaces are printable

my_string = "Python\tSachin"
print(my_string.isprintable()) # Tab is not printable
# Out:
# True
# False
# True
# False

# %% [markdown]
# # 21. string.isspace()

# %%
my_string = "   "
print(my_string.isspace()) # Spaces only

my_string = "\t\n"
print(my_string.isspace()) # Tab and newline are whitespace

my_string = " Python "
print(my_string.isspace()) # Contains letters, so False

my_string = ""
print(my_string.isspace()) # Empty string is False
# Out:
# True
# True
# False
# False

# %% [markdown]
# # 22. string.istitle()

# %%
my_string = "Python Programming"
print(my_string.istitle()) # Each word starts with capital letter

my_string = "Python programming"
print(my_string.istitle()) # programming starts with lowercase p

my_string = "My Name Is Sachin"
print(my_string.istitle()) # All words are title case

my_string = "Python_Sachin"
print(my_string.istitle()) # Words around underscore are title case
# Out:
# True
# False
# True
# True

# %% [markdown]
# # 23. string.isupper()

# %%
my_string = "PYTHON"
print(my_string.isupper()) # All letters are uppercase

my_string = "Python"
print(my_string.isupper()) # ython is lowercase

my_string = "PYTHON123"
print(my_string.isupper()) # Numbers do not affect uppercase check

my_string = "PYTHON_SACHIN"
print(my_string.isupper()) # Underscore does not affect uppercase check
# Out:
# True
# False
# True
# True

# %% [markdown]
# # 24. separator.join(iterable)

# %%
words = ["Python", "is", "easy"]
print(" ".join(words)) # Join list items with space

names = ["Sachin", "Virat", "Rohit"]
print(", ".join(names)) # Join list items with comma and space

letters = ["P", "Y", "T", "H", "O", "N"]
print("-".join(letters)) # Join letters with hyphen

my_string = "ABC"
print("_".join(my_string)) # Join each character with underscore
# Out:
# Python is easy
# Sachin, Virat, Rohit
# P-Y-T-H-O-N
# A_B_C

# %% [markdown]
# # 25. string.ljust(width[, fillchar])

# %%
my_string = "Python"
print(my_string.ljust(10)) # Left align in width 10 using spaces

my_string = "Python"
print(my_string.ljust(10, "-")) # Left align in width 10 using -

my_string = "Hi"
print(my_string.ljust(8, "*")) # Left align in width 8 using *
# Out:
# Python
# Python----
# Hi******

# %% [markdown]
# # 26. string.lower()

# %%
my_string = "PYTHON"
print(my_string.lower()) # Convert uppercase to lowercase

my_string = "Python Programming"
print(my_string.lower()) # Convert mixed case to lowercase

my_string = "PYTHON123"
print(my_string.lower()) # Numbers are unchanged

my_string = "Python_Sachin"
print(my_string.lower()) # Underscore is unchanged
# Out:
# python
# python programming
# python123
# python_sachin

# %% [markdown]
# # 27. string.lstrip([chars])

# %%
my_string = "   Python"
print(my_string.lstrip()) # Remove spaces from left side

my_string = "___Python_sachin"
print(my_string.lstrip("_")) # Remove underscore from left side

my_string = "www.example.com"
print(my_string.lstrip("w.")) # Remove w and dot from left side

my_string = "Python   "
print(my_string.lstrip()) # Right side spaces are not removed
# Out:
# Python
# Python_sachin
# example.com
# Python

# %% [markdown]
# # 28. string.maketrans(x[, y[, z]])

# %%
table = str.maketrans("is", "at")
text = "This is a cat"
result = text.translate(table)
print(result) # i is replaced with a and s is replaced with t

translation_table = str.maketrans("abc", "123", "x")
text = "abcdex"
result = text.translate(translation_table)
print(result) # a, b, c are replaced with 1, 2, 3 and x is deleted

translation_table = str.maketrans("", "", "aei")
text = "hello, amazing world!"
result = text.translate(translation_table)
print(result) # Delete characters a, e, and i

translation_table = str.maketrans({"a": "@", "b": "8", "c": "("})
text = "abcde"
result = text.translate(translation_table)
print(result) # a becomes @, b becomes 8, and c becomes (
# Out:
# That at a cat
# 123de
# hllo, mzng world!
# @8(de

# %% [markdown]
# # 29. string.partition(separator)

# %%
my_string = "python@example.com"
print(my_string.partition("@")) # Split at first @

my_string = "Python_sachin"
print(my_string.partition("_")) # Split at underscore

my_string = "one-two-three"
print(my_string.partition("-")) # Split at first hyphen

my_string = "hello world"
print(my_string.partition("-")) # Separator not found, so last two parts are empty
# Out:
# ('python', '@', 'example.com')
# ('Python', '_', 'sachin')
# ('one', '-', 'two-three')
# ('hello world', '', '')

# %% [markdown]
# # 30. string.removeprefix(prefix)

# %%
my_string = "Mr. Sharma"
print(my_string.removeprefix("Mr. ")) # Remove Mr. from beginning

my_string = "Python_sachin"
print(my_string.removeprefix("Python_")) # Remove Python_ from beginning

my_string = "Hello Python"
print(my_string.removeprefix("Java")) # Prefix not found, string unchanged

my_string = "test_file.py"
print(my_string.removeprefix("test_")) # Remove test_ from beginning
# Out:
# Sharma
# sachin
# Hello Python
# file.py

# %% [markdown]
# # 31. string.removesuffix(suffix)

# %%
my_string = "report.pdf"
print(my_string.removesuffix(".pdf")) # Remove .pdf from end

my_string = "Python_sachin"
print(my_string.removesuffix("_sachin")) # Remove _sachin from end

my_string = "Hello Python"
print(my_string.removesuffix("Java")) # Suffix not found, string unchanged

my_string = "image_backup.png"
print(my_string.removesuffix(".png")) # Remove .png from end
# Out:
# report
# Python
# Hello Python
# image_backup

# %% [markdown]
# # 32. string.replace(old, new[, count])

# %%
my_string = "I like Java"
print(my_string.replace("Java", "Python")) # Replace Java with Python

my_string = "one one one"
print(my_string.replace("one", "two")) # Replace all one with two

my_string = "one one one"
print(my_string.replace("one", "two", 2)) # Replace only first 2 occurrences

my_string = "Python_sachin"
print(my_string.replace("_", " ")) # Replace underscore with space
# Out:
# I like Python
# two two two
# two two one
# Python sachin

# %% [markdown]
# # 33. string.rfind(substring[, start[, end]])

# %%
my_string = "banana"
print(my_string.rfind("a")) # Find last a in full string

my_string = "banana"
print(my_string.rfind("a", 0, 4)) # Find last a from index 0 to before index 4

my_string = "Python_sachin_python"
print(my_string.rfind("python")) # Find last python

my_string = "Python"
print(my_string.rfind("Java")) # Returns -1 because Java is not found
# Out:
# 5
# 3
# 14
# -1

# %% [markdown]
# # 34. string.rindex(substring[, start[, end]])

# %%
my_string = "banana"
print(my_string.rindex("a")) # Find last a in full string

my_string = "banana"
print(my_string.rindex("a", 0, 4)) # Find last a from index 0 to before index 4

my_string = "Python_sachin_Python"
print(my_string.rindex("Python")) # Find last Python

my_string = "Python"
try:
    print(my_string.rindex("Java")) # Gives error because Java is not found
except ValueError:
    print("substring not found")
# Out:
# 5
# 3
# 14
# substring not found

# %% [markdown]
# # 35. string.rjust(width[, fillchar])

# %%
my_string = "Python"
print(my_string.rjust(10)) # Right align in width 10 using spaces

my_string = "Python"
print(my_string.rjust(10, "-")) # Right align in width 10 using -

my_string = "42"
print(my_string.rjust(5, "0")) # Right align in width 5 using 0
# Out:
#     Python
# ----Python
# 00042

# %% [markdown]
# # 36. string.rpartition(separator)

# %%
my_string = "one-two-three"
print(my_string.rpartition("-")) # Split at last hyphen

my_string = "Python_akash_kumar"
print(my_string.rpartition("_")) # Split at last underscore

my_string = "python@example.com"
print(my_string.rpartition("@")) # Split at last @

my_string = "hello world"
print(my_string.rpartition("-")) # Separator not found, first two parts are empty
# Out:
# ('one-two', '-', 'three')
# ('Python_akash', '_', 'kumar')
# ('python', '@', 'example.com')
# ('', '', 'hello world')

# %% [markdown]
# # 37. string.rsplit(separator=None, maxsplit=-1)

# %%
my_string = "apple,banana,cherry"
print(my_string.rsplit(",")) # Split by comma from right, all parts

my_string = "apple,banana,cherry"
print(my_string.rsplit(",", 1)) # Split by comma from right, only 1 split

my_string = "Python_akash_kumar"
print(my_string.rsplit("_", 1)) # Split by underscore from right, only 1 split

my_string = "Python is easy"
print(my_string.rsplit()) # Split by spaces from right
# Out:
# ['apple', 'banana', 'cherry']
# ['apple,banana', 'cherry']
# ['Python_akash', 'kumar']
# ['Python', 'is', 'easy']

# %% [markdown]
# # 38. string.rstrip([chars])

# %% [markdown]
# my_string = "Python   "
# print(my_string.rstrip()) # Remove spaces from right side
#
# my_string = "Python_akash___"
# print(my_string.rstrip("_")) # Remove underscore from right side
#
# my_string = "file.txt"
# print(my_string.rstrip(".txt")) # Remove any dot, t, or x from right side
#
# my_string = "   Python"
# print(my_string.rstrip()) # Left side spaces are not removed

# %% [markdown]
# # 39. string.split(separator=None, maxsplit=-1)

# %%
my_string = "Python is easy"
print(my_string.split()) # Split by spaces

my_string = "Python_akash"
print(my_string.split(sep="_", maxsplit=-1)) # Split by underscore, all parts

my_string = "apple,banana,cherry"
print(my_string.split(",")) # Split by comma, all parts

my_string = "apple,banana,cherry"
print(my_string.split(",", 1)) # Split by comma, only 1 split from left
# Out:
# ['Python', 'is', 'easy']
# ['Python', 'akash']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana,cherry']

# %% [markdown]
# # 40. string.splitlines(keepends=False)

# %%
my_string = "Python\nJava\nC++"
print(my_string.splitlines()) # Split lines and remove line break characters

my_string = "Python\nJava\nC++"
print(my_string.splitlines(keepends=True)) # Split lines and keep line break characters

my_string = "line1\r\nline2"
print(my_string.splitlines()) # Split Windows-style line break

my_string = "single line"
print(my_string.splitlines()) # No line break, returns one item
# Out:
# ['Python', 'Java', 'C++']
# ['Python\n', 'Java\n', 'C++']
# ['line1', 'line2']
# ['single line']

# %% [markdown]
# # 41. string.startswith(prefix[, start[, end]])

# %%
my_string = "Python Programming"
print(my_string.startswith("P")) # Is string starting with P?
print(my_string.startswith("Python")) # Is string starting with Python?
print(my_string.startswith("P", 7)) # Is P starting from index 7?
print(my_string.startswith("Pro", 7)) # Is Pro starting from index 7?
print(my_string.startswith("Programming", 7, 18)) # Is Programming starting between index 7 and 18?

my_string = "main.py"
print(my_string.startswith(("main", "test"))) # Is string starting with main or test?
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# # 42. string.strip([chars])

# %%
my_string = "python programming"
print(my_string.title()) # First letter of each word becomes uppercase

my_string = "python_sachin"
print(my_string.title()) # First letter after underscore also becomes uppercase

my_string = "hello world 123"
print(my_string.title()) # Numbers are unchanged

my_string = "python's class"
print(my_string.title()) # Title case is applied around apostrophe too
# Out:
# Python Programming
# Python_Sachin
# Hello World 123
# Python'S Class

# %% [markdown]
# # 43. string.swapcase()

# %% [markdown]
# #Converts lowercase letters to uppercase and uppercase letters to lowercase.

# %%
my_string = "AkaSh"
print(my_string.swapcase()) # Lowercase becomes uppercase and uppercase becomes lowercase

my_string = "Python_akash"
print(my_string.swapcase()) # Swap case around underscore too

my_string = "HELLO world"
print(my_string.swapcase()) # HELLO becomes hello and world becomes WORLD

my_string = "Python123"
print(my_string.swapcase()) # Numbers are unchanged
# Out:
# aKAsH
# pYTHON_AKASH
# hello WORLD
# pYTHON123

# %% [markdown]
# # 44. string.title()# 44. string.title()

# %% [markdown]
# #Converts the first letter of each word to uppercase.

# %%
my_string = "python programming"
print(my_string.title()) # First letter of each word becomes uppercase

my_string = "python_sachin"
print(my_string.title()) # First letter after underscore also becomes uppercase

my_string = "hello world 123"
print(my_string.title()) # Numbers are unchanged

my_string = "python's class"
print(my_string.title()) # Title case is applied around apostrophe too
# Out:
# Python Programming
# Python_Sachin
# Hello World 123
# Python'S Class

# %% [markdown]
# # 45. string.translate(table)

# %% [markdown]
# Returns a translated string using a translation table created by maketrans().

# %%
table = str.maketrans("is", "at")
text = "This is a cat"
print(text.translate(table)) # Apply table: i -> a and s -> t

translation_table = str.maketrans("abc", "123", "x")
text = "abcdex"
print(text.translate(translation_table)) # Replace a, b, c and delete x

translation_table = str.maketrans("", "", "aei")
text = "hello, amazing world!"
print(text.translate(translation_table)) # Delete a, e, and i

translation_table = str.maketrans({"a": "@", "b": "8", "c": "("})
text = "abcde"
print(text.translate(translation_table)) # Use dictionary translation table
# Out:
# That at a cat
# 123de
# hllo, mzng world!
# @8(de

# %% [markdown]
# # 46. string.upper()

# %% [markdown]
# Converts all alphabet letters to uppercase.

# %%
my_string = "python"
print(my_string.upper()) # Convert lowercase to uppercase

my_string = "Python_sachin"
print(my_string.upper()) # Convert letters around underscore to uppercase

my_string = "python123"
print(my_string.upper()) # Numbers are unchanged

my_string = "Python Programming"
print(my_string.upper()) # Convert full sentence to uppercase
# Out:
# PYTHON
# PYTHON_SACHIN
# PYTHON123
# PYTHON PROGRAMMING

# %% [markdown]
# # 47. string.zfill(width)

# %% [markdown]
# Adds zeros at the beginning of the string until it reaches the given width.

# %%
my_string = "42"
print(my_string.zfill(5)) # Add zeros to make width 5

my_string = "-42"
print(my_string.zfill(5)) # Add zeros after minus sign

my_string = "123456"
print(my_string.zfill(4)) # Width already smaller, so string unchanged

my_string = "7"
print(my_string.zfill(3)) # Add zeros to make width 3
# Out:
# 00042
# -0042
# 123456
# 007
